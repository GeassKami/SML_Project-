# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.externals import joblib
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pickle
# Out:
# C:\Users\suraj\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
filename = "Diabetes_Readmission_Completed_model.joblib"
loaded_model = joblib.load(filename)

# %%
# Feature range along with data scale/type

#num_lab_procedures range 1 to 121
#diabetesMed is yes /no
#num_medications range 0 to 81
#time_in_hospital range 1 to 15
#number_diagnoses  range 1 to 15
#discharge_disposition_id  range 0 to 50
#number_emergency range 0 to 65
#number_inpatient range 1 to 21

# %%
# print()
print('### DIABETES READMISSION RECOMENDATION SYSTEM ### ')
print()
print('__Instructions___')
print()
print('Please ensure data entered be for single paitent only')
print()
print('Ideally the ranges of certain conditions must be:')
print()
print('---------------------------------------------------------------------------')
print('Number of lab procedures range in 1 to 121')
print('Number of Medications range in 0 to 81')
print('Time in hospital range in 1 to 15')
print('Number of diagnoses  range in  1 to 15')
print('Discharge disposition id  range in  0 to 50')
print('Number of emergency range in  0 to 65')
print('Number of inpatient range in 1 to 21')
print('----------------------------------------------------------------------------')
print()
print('----------------------------------------------------------------------------')
print('......Please Enter Following Required Information........')
print('----------------------------------------------------------------------------')
print()
print('**Metaforming Conditions** ')
print()
lit=['No = 0','Steady = 1','Up = 2','Down = 3']
print('Enter right condition: /n',lit)
metformin = int(input('Please enter the Metforming  condition :  '))
print()
print('**Number of Medications**  ')
print()
num_medications = input('Enter Number of distinct generic names administered during the encounter  :   ')
print()
print('**Time_in_hospital**  ')
print()
time_in_hospital = input('Integer number of days between admission and discharge  :   ') 
print()
print('**Number_diagnoses**  ')
print()
number_diagnoses  = input('Number of diagnoses entered to the system  :   ')
print()
print('**Discharge_disposition_id** ')
print()
discharge_disposition_id  = input('Integer identifier corresponding to 29 distinct values (i.e:discharge_disposition_id) :  ')
print()
print('**Number_Emergency**  ')
print()
number_emergency = input('Number of emergency visits of the patient in the year preceding the encounter  :   ')
print()
print('**Number_Inpatient**  ')
print()
number_inpatient = input('Number of inpatient visits of the patient in the year preceding the encounter :  ') 
print()
print('**Diabetic medicationt**  ')
print()
diabetesMed= int(input(' Indicates if there was any diabetic medication prescribed. Values: “yes” and “no  [yes = 1 and No = 0] :  '))
print()

X = [[discharge_disposition_id, time_in_hospital, num_medications,
       number_emergency, number_inpatient, number_diagnoses, metformin,
       diabetesMed]]
X1 = ['discharge_disposition_id', 'time_in_hospital', 'num_medications',
       'number_emergency', 'number_inpatient', 'number_diagnoses', 'metformin',
       'diabetesMed']
print()
print('Data Processing.....')
print()
print('************************************************************************************************************')
Y = loaded_model.predict(X)
if Y == 1:
    print()
    print('......Based On your conditions following is the situation related to severity of readmission')
    print()
    print('A readmission in less than 30 days is required')
    print()
    print('This situation is not good, because maybe your treatment was not appropriate!!!')
else:
    print('......Based On your conditions following is the situation related to severity of readmission')
    print()
    print('A readmission in more than 30 days is required')
    print()
    print('This one is not so good as well the last one, however, the reason can be the state of the patient!')
# Out:
# ### DIABETES READMISSION RECOMENDATION SYSTEM ###
#
# __Instructions___
#
# Please ensure data entered be for single paitent only
#
# Ideally the ranges of certain conditions must be:
#
# ---------------------------------------------------------------------------
# Number of lab procedures range in 1 to 121
# Number of Medications range in 0 to 81
# Time in hospital range in 1 to 15
# Number of diagnoses  range in  1 to 15
# Discharge disposition id  range in  0 to 50
# Number of emergency range in  0 to 65
# Number of inpatient range in 1 to 21
# ----------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# ......Please Enter Following Required Information........
# ----------------------------------------------------------------------------
#
# **Metaforming Conditions**
#
# Enter right condition: /n ['No = 0', 'Steady = 1', 'Up = 2', 'Down = 3']
# ...
